# %%
import pandas as pd
import numpy as np

# %%
print(" pandas is the best data manipulation tool I have used. ")
# Out:
#  pandas is the best data manipulation tool I have used.

# %%
print(" I freaking love Python and C++.")
# Out:
#  I freaking love Python and C++.|
